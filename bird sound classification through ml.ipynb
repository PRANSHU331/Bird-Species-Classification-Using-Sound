# %% [markdown]
# # Bird Sound Classification Through Artificial Nurale Network

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[10]
    y_to_predict = y_test[10]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 638, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 319, 6, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 319, 6, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 317, 4, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 159, 2, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 159, 2, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 158, 1, 32)        4128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 79, 1, 32)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 79, 1, 32)         128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2528)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                161856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 176,586
# Trainable params: 176,394
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 10/10 [==============================] - 2s 172ms/step - loss: 3.0214 - accuracy: 0.1681 - val_loss: 4.5769 - val_accuracy: 0.0267
# Epoch 2/30
# 10/10 [==============================] - 2s 158ms/step - loss: 1.7893 - accuracy: 0.3954 - val_loss: 3.0097 - val_accuracy: 0.1200
# Epoch 3/30
# 10/10 [==============================] - 2s 157ms/step - loss: 1.2488 - accuracy: 0.5665 - val_loss: 2.3664 - val_accuracy: 0.3200
# Epoch 4/30
# 10/10 [==============================] - 2s 161ms/step - loss: 1.0956 - accuracy: 0.6334 - val_loss: 2.1001 - val_accuracy: 0.3733
# Epoch 5/30
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6878 - accuracy: 0.7849 - val_loss: 1.8931 - val_accuracy: 0.4000
# Epoch 6/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.5583 - accuracy: 0.8688 - val_loss: 1.7021 - val_accuracy: 0.4133
# Epoch 7/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.4974 - accuracy: 0.8736 - val_loss: 1.5144 - val_accuracy: 0.4533
# Epoch 8/30
# 10/10 [==============================] - 2s 178ms/step - loss: 0.4104 - accuracy: 0.9140 - val_loss: 1.3660 - val_accuracy: 0.4533
# Epoch 9/30
# 10/10 [==============================] - 2s 156ms/step - loss: 0.3454 - accuracy: 0.9099 - val_loss: 1.2269 - val_accuracy: 0.5200
# Epoch 10/30
# 10/10 [==============================] - 2s 175ms/step - loss: 0.3337 - accuracy: 0.9302 - val_loss: 1.1025 - val_accuracy: 0.5333
# Epoch 11/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.2810 - accuracy: 0.9328 - val_loss: 0.9874 - val_accuracy: 0.5467
# Epoch 12/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.2308 - accuracy: 0.9530 - val_loss: 0.8875 - val_accuracy: 0.6267
# Epoch 13/30
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1950 - accuracy: 0.9438 - val_loss: 0.8036 - val_accuracy: 0.6400
# Epoch 14/30
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1737 - accuracy: 0.9790 - val_loss: 0.7149 - val_accuracy: 0.7333
# Epoch 15/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1850 - accuracy: 0.9750 - val_loss: 0.6256 - val_accuracy: 0.8000
# Epoch 16/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1490 - accuracy: 0.9832 - val_loss: 0.5447 - val_accuracy: 0.8400
# Epoch 17/30
# 10/10 [==============================] - 2s 169ms/step - loss: 0.1548 - accuracy: 0.9603 - val_loss: 0.4885 - val_accuracy: 0.8800
# Epoch 18/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1374 - accuracy: 0.9904 - val_loss: 0.4188 - val_accuracy: 0.8933
# Epoch 19/30
# 10/10 [==============================] - 2s 167ms/step - loss: 0.1211 - accuracy: 0.9788 - val_loss: 0.3593 - val_accuracy: 0.9200
# Epoch 20/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.1149 - accuracy: 0.9848 - val_loss: 0.3027 - val_accuracy: 1.0000
# Epoch 21/30
# 10/10 [==============================] - 2s 178ms/step - loss: 0.1049 - accuracy: 0.9793 - val_loss: 0.2626 - val_accuracy: 1.0000
# Epoch 22/30
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1016 - accuracy: 0.9778 - val_loss: 0.2474 - val_accuracy: 0.9467
# Epoch 23/30
# 10/10 [==============================] - 2s 195ms/step - loss: 0.1062 - accuracy: 0.9895 - val_loss: 0.2138 - val_accuracy: 1.0000
# Epoch 24/30
# 10/10 [==============================] - 2s 187ms/step - loss: 0.0907 - accuracy: 0.9942 - val_loss: 0.1758 - val_accuracy: 1.0000
# Epoch 25/30
# 10/10 [==============================] - 2s 190ms/step - loss: 0.0841 - accuracy: 0.9869 - val_loss: 0.1528 - val_accuracy: 1.0000
# Epoch 26/30
# 10/10 [==============================] - 2s 167ms/step - loss: 0.0720 - accuracy: 0.9821 - val_loss: 0.1459 - val_accuracy: 1.0000
# Epoch 27/30
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0726 - accuracy: 0.9900 - val_loss: 0.1177 - val_accuracy: 1.0000
# Epoch 28/30
# 10/10 [==============================] - 2s 175ms/step - loss: 0.0665 - accuracy: 0.9967 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 29/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0652 - accuracy: 0.9966 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 30/30
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0699 - accuracy: 0.9907 - val_loss: 0.0749 - val_accuracy: 1.0000
# 4/4 - 0s - loss: 0.0516 - accuracy: 1.0000
#
# Test accuracy: 1.0
# Target: 7, Predicted label: [7]

# %% [markdown]
# # CNN model for bird sound classification

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.0))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[10]
    y_to_predict = y_test[10]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 638, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 319, 6, 32)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 319, 6, 32)        128
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 317, 4, 32)        9248
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 159, 2, 32)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 159, 2, 32)        128
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 158, 1, 32)        4128
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 79, 1, 32)         0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 79, 1, 32)         128
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2528)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                161856
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                650
# =================================================================
# Total params: 176,586
# Trainable params: 176,394
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 10/10 [==============================] - 2s 193ms/step - loss: 2.6705 - accuracy: 0.1807 - val_loss: 4.4854 - val_accuracy: 0.1467
# Epoch 2/30
# 10/10 [==============================] - 2s 172ms/step - loss: 1.2476 - accuracy: 0.5723 - val_loss: 3.2244 - val_accuracy: 0.1467
# Epoch 3/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.6714 - accuracy: 0.8836 - val_loss: 2.6348 - val_accuracy: 0.1733
# Epoch 4/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4260 - accuracy: 0.9441 - val_loss: 2.3581 - val_accuracy: 0.2000
# Epoch 5/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3167 - accuracy: 0.9806 - val_loss: 2.0937 - val_accuracy: 0.2267
# Epoch 6/30
# 10/10 [==============================] - 2s 164ms/step - loss: 0.2348 - accuracy: 0.9720 - val_loss: 1.8659 - val_accuracy: 0.3333
# Epoch 7/30
# 10/10 [==============================] - 2s 167ms/step - loss: 0.1590 - accuracy: 0.9942 - val_loss: 1.6771 - val_accuracy: 0.4133
# Epoch 8/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.1388 - accuracy: 0.9935 - val_loss: 1.5098 - val_accuracy: 0.4933
# Epoch 9/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.0945 - accuracy: 0.9983 - val_loss: 1.3466 - val_accuracy: 0.6000
# Epoch 10/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 1.2112 - val_accuracy: 0.6000
# Epoch 11/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 1.0849 - val_accuracy: 0.7067
# Epoch 12/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.9635 - val_accuracy: 0.7333
# Epoch 13/30
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.8379 - val_accuracy: 0.7467
# Epoch 14/30
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.7399 - val_accuracy: 0.7733
# Epoch 15/30
# 10/10 [==============================] - 2s 165ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.6571 - val_accuracy: 0.8400
# Epoch 16/30
# 10/10 [==============================] - 2s 167ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.8933
# Epoch 17/30
# 10/10 [==============================] - 2s 166ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.9067
# Epoch 18/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.9067
# Epoch 19/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.3566 - val_accuracy: 0.9467
# Epoch 20/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.9867
# Epoch 21/30
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.2458 - val_accuracy: 1.0000
# Epoch 22/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 1.0000
# Epoch 23/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 1.0000
# Epoch 24/30
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 1.0000
# Epoch 25/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 1.0000
# Epoch 26/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 27/30
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 28/30
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 29/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 1.0000
# Epoch 30/30
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 1.0000
# 4/4 - 0s - loss: 0.0585 - accuracy: 1.0000
#
# Test accuracy: 1.0
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020186DC4620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Target: 8, Predicted label: [8]
